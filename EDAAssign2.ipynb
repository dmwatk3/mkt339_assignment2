# %% [markdown]
# <a href="https://colab.research.google.com/github/dmwatk3/mkt339_assignment2/blob/main/EDAAssign2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cd9a221d-8ed4-4a42-8bbc-f26db0783f65" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd9a221d-8ed4-4a42-8bbc-f26db0783f65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
ad_dataset = pd.read_csv(io.BytesIO(uploaded['ad_dataset_withheaders.csv']))

# %%
ad_dataset.head(10)
# Out:
#    Site_Time  Age  DailyTime  Gender AdClicking
# 0      68.95   35     256.09  Female         No
# 1      80.23   31     193.77    Male         No
# 2      69.47   26     236.50  Female         No
# 3      74.15   29     245.89    Male         No
# 4      68.37   35     225.58  Female         No
# 5      59.99   23     226.74    Male         No
# 6      88.91   33     208.36  Female         No
# 7      66.00   48     131.76    Male        Yes
# 8      74.53   30     221.51    Male         No
# 9      69.88   20     183.82    Male         No

# %%
ad_dataset.describe()
# Out:
#          Site_Time          Age    DailyTime
# count  1000.000000  1000.000000  1000.000000
# mean     65.000200    36.009000   180.000100
# std      15.853615     8.785562    43.902339
# min      32.600000    19.000000   104.780000
# 25%      51.360000    29.000000   138.830000
# 50%      68.215000    35.000000   183.130000
# 75%      78.547500    42.000000   218.792500
# max      91.430000    61.000000   269.960000

# %%
ad_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Site_Time   1000 non-null   float64
#  1   Age         1000 non-null   int64
#  2   DailyTime   1000 non-null   float64
#  3   Gender      1000 non-null   object
#  4   AdClicking  1000 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 39.2+ KB

# %%
ad_dataset['Gender'].value_counts()
# Out:
# Female    519
# Male      481
# Name: Gender, dtype: int64

# %%
ad_dataset.corr()
# Out:
#            Site_Time       Age  DailyTime
# Site_Time   1.000000 -0.331513   0.518658
# Age        -0.331513  1.000000  -0.367209
# DailyTime   0.518658 -0.367209   1.000000

# %%
sns.heatmap(ad_dataset.corr(), annot = True)

# %%
sns.heatmap(ad_dataset.corr(), cmap= "YlGnBu")

# %%
sns.pairplot(ad_dataset)

# %%
sns.scatterplot(x="Site_Time", y="Age", data=ad_dataset)

# %%
sns.lmplot(x="Site_Time", y="Age", data=ad_dataset)

# %%
sns.scatterplot(x="Site_Time", y="Age", hue="Gender", data=ad_dataset)

# %%
sns.lmplot(x = "Site_Time", y = "Age", hue="Gender", data = ad_dataset)

# %%
sns.countplot(x='Gender', data=ad_dataset)

# %%
sns.countplot(x='Gender', data=ad_dataset, color='b')

# %%
ad_dataset_Gender=ad_dataset.groupby("Gender")
ad_dataset_Gender.mean()
# Out:
#         Site_Time        Age   DailyTime
# Gender
# Female  65.289287  36.186898  178.816763
# Male    64.688274  35.817048  181.276923

# %%
sns.boxplot(x="Gender", y="Site_Time", data=ad_dataset)

# %%
sns.boxplot(x="Gender", y="Site_Time", hue="Gender", data=ad_dataset)

# %%
ad_dataset_top3_ad_dataset = ad_dataset.nlargest(3, "Site_Time")
ad_dataset_top3_ad_dataset
# Out:
#      Site_Time  Age  DailyTime  Gender AdClicking
# 533      91.43   39     209.91    Male         No
# 860      91.37   45     182.65    Male        Yes
# 927      91.15   38     184.98  Female         No
